# %% [markdown]
# # [Руководство пользователя Терминала](#Руководство-пользователя-Терминала)
#
# [(URL)](https://support.apple.com/ru-ru/guide/terminal/welcome/mac)
#
# - [ ] Добро пожаловать!
# - [x] [Что такое Терминал?](#Что-такое-Терминал-на-Mac?)
# - [x] [ Начало работы с Терминалом на Mac](#Начало-работы-с-Терминалом-на-Mac)
# - [x] [Работа в окнах Терминала](#Работа-в-окнах-Терминала)
#     - [x] [Открытие и завершение приложения «Терминал»](#Открытие-и-завершение-приложения-«Терминал»-на-Mac)
#     - [x] [Открытие новых окон и вкладок Терминала](#Открытие-новых-окон-и-вкладок-Терминала-на-Mac)
#     - [x] [Выполнение команд и запуск инструментов](#Выполнение-команд-и-запуск-инструментов-в-приложении-«Терминал»-на-Mac)
#     - [x] [Указание файлов и папок](#Выбор-файлов-и-папок-в-приложении-«Терминал»-на-Mac)
#     - [ ] [Перенаправление ввода и вывода Терминала](#Перенаправление-ввода-и-вывода-в-приложении-«Терминал»-на-Mac)
#     - [ ] Исправление опечаток
#     - [ ] Перетягивание объектов в окно Терминала
#     - [ ] Использование групп окон
# - › Индивидуальная настройка Терминала (#2)
# - › Использование автоматизации задач и скриптов(#2)
# - Сочетания клавиш(#2)
# - Авторские права(#2)
#
#
# --------------------------------------

# %% [markdown]
# # [Что такое Терминал на Mac?](#Руководство-пользователя-Терминала)
#
# [(URL)](https://support.apple.com/ru-ru/guide/terminal/trmld4c92d55/mac)
#
# Терминал — это приложение для опытных пользователей и разработчиков, которое дает возможность взаимодействовать с операционной системой Mac через интерфейс командной строки. В Терминале можно вводить команды и скрипты (так называемые shell-скрипты) для выполнения задач на Mac.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# При открытии Терминала отображается простое окно с приглашением в командную строку. В Терминале доступен широкий выбор команд и параметров, которые можно использовать для выполнения любых задач: от простых до очень сложных. Подробнее об отображении и использовании команд в Терминале см. в статье Чтение справочных страниц UNIX (на английском языке) на сайте Apple для разработчиков.

# %% [markdown]
# В отличие от обычных приложений Mac, где используется графический интерфейс — кнопки, бегунки и меню, — в Терминале для выполнения задач и доступа к функциям нужно вводить код в интерфейсе командной строки. Такие команды (и последовательности команд, отправляемые в виде скриптов) выполняются оболочкой (shell), которая представляет собой пользовательский интерфейс операционной системы UNIX.

# %% [markdown]
# В Терминале можно выполнять команды и скрипты, которые сообщают оболочке (shell), что необходимо сделать. Например, с помощью команды можно показать содержимое папки или запустить скрипт, автоматизирующий открытие приложения и выполнение определенной задачи.

# %% [markdown]
# Также с помощью простых скриптов в Терминале можно экономить время и автоматизировать часто выполняемые задачи. Когда Вам требуется автоматизация задач или работа со скриптами на быстрых низкоуровневых языках программирования, Терминал предоставляет легкий доступ к вводу и выводу командных оболочек UNIX, в том числе BASH и ZSH.

# %% [markdown]
# Подробнее об использовании Терминала и создании скриптов см. в статье Основные сведения о shell-скриптах на сайте Apple для разработчиков.

# %% [markdown]
# Примечание. Приложение «Терминал» также может быть полезно при устранении проблем на Mac с помощью службы поддержки Apple. Рекомендуется не удалять это приложение с компьютера.

# %% [markdown]
# См. также
#
# [Выполнение команд и запуск инструментов в приложении «Терминал» на Mac](https://support.apple.com/ru-ru/guide/terminal/apdb66b5242-0d18-49fc-9c47-a2498b7c91d5/2.14/mac/15.0)
#
# [Сочетания клавиш приложения «Терминал» на Mac](https://support.apple.com/ru-ru/guide/terminal/trmlshtcts/2.14/mac/15.0)
#
# -------------------------------

# %% [markdown]
# # [Начало работы с Терминалом на Mac](#Руководство-пользователя-Терминала)
#
# [(URL)](https://support.apple.com/ru-ru/guide/terminal/pht23b129fed/mac)
#
# Терминал — это приложение, позволяющее выполнять задачи с помощью интерфейса командной строки в macOS.

# %% [markdown]
# # Использование командной строки
#
# С помощью командной строки в Терминале можно быстро выполнять команды, а также запускать инструменты и shell-скрипты. Например, чтобы просмотреть список файлов в папке по умолчанию, введите команду списка ls, а затем нажмите клавишу Return. По завершении очистите окно списка, выбрав меню «Правка» > «Очистить окно».

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Поиск нужных команд
# Для поиска команд UNIX можно использовать команду man. Она отображает справочные страницы, называемые man‑страницами. Чтобы отобразить man‑страницу со сведениями о команде man, введите команду man man, затем нажмите клавишу Return. Чтобы закрыть man‑страницу и очистить окно, нажмите клавишу q.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Настройка окон Терминала
# Можно изменить оформление окон Терминала, чтобы легко различать их, когда у Вас одновременно открыто несколько окон. Чтобы отобразить параметры окна, выберите меню «Терминал» > «Настройки», затем нажмите «Профили».

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Готовы создавать скрипты?
# Если Вы только начинаете создавать скрипты, изучите страницу сайта Apple для разработчиков: Основные сведения о shell-скриптах. На ней можно узнать больше о работе с shell-скриптами в приложении «Терминал».

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Хотите узнать больше?
#
# [Использование профилей для изменения внешнего вида окон Терминала](https://support.apple.com/ru-ru/guide/terminal/trml107/2.14/mac/15.0)
#
# [Сайт Apple для разработчиков: Чтение справочных страниц UNIX (на английском языке)](https://developer.apple.com/documentation/os/reading_unix_manual_pages)
#
# [Управление файлами в Терминале](https://support.apple.com/ru-ru/guide/terminal/apddfb31307-3e90-432f-8aa7-7cbc05db27f7/2.14/mac/15.0|)
#
# ------------------

# %% [markdown]
# # [Работа в окнах Терминала](#Руководство-пользователя-Терминала)
#
# - Работа в окнах Терминала
#     - Открытие и завершение приложения «Терминал»
#     - Открытие новых окон и вкладок Терминала
#     - Выполнение команд и запуск инструментов
#     - Указание файлов и папок
#     - Перенаправление ввода и вывода Терминала
#     - Исправление опечаток
#     - Перетягивание объектов в окно Терминала
#     - Использование групп окон
#
# # [Открытие и завершение приложения «Терминал» на Mac](#Руководство-пользователя-Терминала)
#
# [(URL)](https://support.apple.com/ru-ru/guide/terminal/apd5265185d-f365-44cb-8b09-71a064a42125/mac)
#
# В приложении «Терминал» можно управлять macOS с помощью интерфейса командной строки. Каждое окно в Терминале представляет свой экземпляр процесса shell. Окно содержит приглашение, которое означает, что можно вводить команду. Отображаемое приглашение зависит от настроек Терминала и shell, однако обычно оно включает имя хоста, к которому Вы подключены, Вашу текущую рабочую папку, Ваше имя пользователя и символ приглашения. Например, если пользователь с именем michael использует по умолчанию оболочку zsh, приглашение выглядит следующим образом:
#
#     michael@MacBook-Pro ~ %
#
# В приглашении указано, что пользователь с именем michael вошел в систему на компьютере с именем MacBook-Pro и текущей папкой является его папка пользователя, обозначаемая тильдой (~).

# %% [markdown]
# # Открытие Терминала
#
# На компьютере Mac выполните одно из следующих действий.
# - Нажмите значок Launchpad ![image.png](attachment:image.png) в панели Dock, введите «Терминал» в поле поиска и нажмите значок Терминала.
# - В окне Finder ![image-2.png](attachment:image-2.png) откройте папку «Программы/Утилиты» и дважды нажмите приложение «Терминал».
# В открытом окне Терминала можно выполнять команды и запускать инструменты.

# %% [markdown]
# # Завершение приложения «Терминал»
# Откройте приложение «Терминал» ![image.png](attachment:image.png) на Mac.
# Выберите «Терминал» > «Завершить Терминал».

# %% [markdown]
# # Завершение сеанса shell
# Откройте приложение «Терминал» ![image.png](attachment:image.png)  на Mac.
# В окне с запущенным процессом shell, который Вы хотите завершить, введите exit и нажмите клавишу Return.
# Это обеспечит закрытие всех текущих команд, выполняемых в shell. Если что-то продолжает выполняться, появляется диалоговое окно.
# Если Вы хотите изменить поведение приложения при выходе из shell, см. Изменение настроек shell для профилей.

# %% [markdown]
# См. также
#
# [Изменение оболочки shell по умолчанию в Терминале на Mac](https://support.apple.com/ru-ru/guide/terminal/trml113/2.14/mac/15.0)
#
# [Открытие новых окон и вкладок Терминала на Mac](https://support.apple.com/ru-ru/guide/terminal/trmlb20c7888/2.14/mac/15.0)
#
# [Использование профилей для изменения внешнего вида окон Терминала на Mac](https://support.apple.com/ru-ru/guide/terminal/trml107/2.14/mac/15.0)
#
# [Сайт Apple для разработчиков: Основные сведения о командной строке (на английском языке)](https://developer.apple.com/library/content/documentation/OpenSource/Conceptual/ShellScripting/CommandLInePrimer/CommandLine.html)
#
# -------------

# %% [markdown]
# # [Открытие новых окон и вкладок Терминала на Mac](#Руководство-пользователя-Терминала)
#
# [(URL)](https://support.apple.com/ru-ru/guide/terminal/trmlb20c7888/mac)
#
# При открытии новых окон и вкладок Терминала может использоваться профиль по умолчанию, профиль активного окна или вкладки, а также выбранный Вами профиль.
# В разделе настроек «Основные» можно выбрать профили, которые будут использоваться при открытии новых окон и вкладок. Если Вы не выбрали профиль по умолчанию, используется профиль Basic (см. Выбор профиля по умолчанию и загрузочного профиля окна Терминала)

# %% [markdown]
# # Открытие новых окон Терминала с профилем по умолчанию или с тем же профилем, который используется в активном окне
# Открываемый профиль (профиль по умолчанию или тот же профиль, который используется в активном окне) зависит от значения параметра «В новых окнах открывать» в разделе настроек «Основные».

# %% [markdown]
# - Откройте приложение «Терминал» ![image.png](attachment:image.png) на Mac.
# - Выполните одно из следующих действий.
#     - Нажмите сочетание клавиш Command-N.
#     - Выберите пункт меню «Shell» > «Новое окно» > «Новое окно с профилем».
# Имя открываемого профиля добавляется к пункту «Новое окно» в меню «Профиль».

# %% [markdown]
# # Открытие новых окон Терминала с выбранным профилем
# - Откройте приложение «Терминал» ![image.png](attachment:image.png) на Mac.
# - Выполните одно из следующих действий.
#     - Выберите «Shell» > «Новое окно», затем выберите профиль из списка профилей в конце меню.
#     - Выберите «Терминал» > «Настройки», затем нажмите «Профили». В списке профилей дважды нажмите значок профиля, который хотите использовать.

# %% [markdown]
# # Открытие новых вкладок с профилем по умолчанию или с тем же профилем, который используется в активной вкладке
# Открываемый профиль (профиль по умолчанию или тот же профиль, который используется в активной вкладке) зависит от значения параметра «В новых вкладках открывать» в разделе настроек «Основные».
# - Откройте приложение «Терминал» ![image.png](attachment:image.png) на Mac.
# - Выполните одно из следующих действий.
#     - Нажмите сочетание клавиш Command-T.
#     - Выберите пункт меню «Shell» > «Новая вкладка» > «Новая вкладка с профилем».
# Имя открываемого профиля добавляется к пункту «Новая вкладка» в меню «Профиль».

# %% [markdown]
# # Открытие новых вкладок с выбранным профилем
# - Откройте приложение «Терминал» ![image.png](attachment:image.png) на Mac.
# - Выберите «Shell» > «Новая вкладка», затем выберите профиль из списка профилей в конце меню.

# %% [markdown]
# # Открытие новых окон или вкладок Терминала из Finder
# Для открытия нового окна или вкладки Терминала можно использовать строку пути в окне Finder, указав расположение папки в качестве рабочей директории.
# - На Mac откройте окно Finder, затем перейдите к папке, которую нужно использовать.
# - Если строка пути не отображается в нижней части окна Finder, выберите «Вид» > «Показать строку пути».
# - Нажмите папку в строке пути, удерживая клавишу Control, затем выполните любое из указанных ниже действий.
#     - Открытие нового окна. Выберите «Открыть в Терминале».
#     - Открытие новой вкладки. Выберите «Службы» > «Новая вкладка терминала по адресу папки».

# %% [markdown]
# См. также
#
# [Использование профилей для изменения внешнего вида окон Терминала на Mac](https://support.apple.com/ru-ru/guide/terminal/trml107/2.14/mac/15.0)
#
# [Выбор профиля по умолчанию и загрузочного профиля окна Терминала на Mac](https://support.apple.com/ru-ru/guide/terminal/trml5856b1f2/2.14/mac/15.0)
#
# [Изменение настроек раздела «Основные» в Терминале на Mac](https://support.apple.com/ru-ru/guide/terminal/trmlstrtup/2.14/mac/15.0)
#
# -----------

# %% [markdown]
# # [Выполнение команд и запуск инструментов в приложении «Терминал» на Mac](#Руководство-пользователя-Терминала)
#
# [(URL)](https://support.apple.com/ru-ru/guide/terminal/apdb66b5242-0d18-49fc-9c47-a2498b7c91d5/mac)
#
# Среду командной строки можно использовать в интерактивном режиме, то есть вводить команду и ждать результат. Вы также можете составить shell-скрипт, который будет выполняться без Вашего непосредственного участия. Для получения подробной информации о командах ознакомьтесь с документацией для низкоуровневых инструментов UNIX и API в приложении «Терминал». См. статью Чтение справочных страниц в UNIX (на английском языке) на веб‑сайте Apple для разработчиков.

# %% [markdown]
# # [Выполнение команд в оболочке shell](#Руководство-пользователя-Терминала)
#
# Откройте приложение «Терминал» ![image.png](attachment:image.png) на Mac.
#
#
#
# Введите полный путь к исполняемому файлу инструмента, затем введите все необходимые аргументы и нажмите клавишу Return.
#
#
# Если команда находится в одной из известных папок shell, при вводе имени команды можно не указывать путь. Список известных папок хранится в переменной среды PATH оболочки shell и включает папки, содержащие большинство инструментов командной строки.
#
#
# Например, чтобы выполнить команду ls в папке текущего пользователя, введите следующую команду в командной строке, затем нажмите Return:
#
#     % ls
#
#
# Чтобы выполнить команду в папке текущего пользователя, введите перед командой спецификатор папки. Например, чтобы выполнить MyCommandLineProg, используйте следующую команду:
#
#     % ~/MyCommandLineProg
#
#
# Чтобы открыть приложение, используйте команду open:
#
#     % open -a MyProg.app
#
#
# Если при вводе команды отображается сообщение command not found, проверьте правильность написания. Пример:
#
#     % opne -a TextEdit.app
#     zsh: opne: command not found
#
#
#
# Другие доступные команды см. на сайте Apple для разработчиков в разделе [Основные сведения о командной строке (на английском языке)](https://developer.apple.com/library/content/documentation/OpenSource/Conceptual/ShellScripting/CommandLInePrimer/CommandLine.html).

# %% [markdown]
# # Прерывание команд
# - Откройте приложение «Терминал» ![image.png](attachment:image.png) на Mac.
# - Нажмите окно Терминала, где выполняется команда, которую Вы хотите завершить.
# - Нажмите сочетание клавиш Control-C.
#
# Будет отправлен сигнал, который вызывает прерывание большинства команд.

# %% [markdown]
# # Повтор ранее введенных команд
# Введенные в текущем сеансе команды сохраняются, так что Вы можете повторить ранее использованную команду, не вводя ее снова.
# - Откройте приложение «Терминал» ![image.png](attachment:image.png) на Mac.
# - Нажать клавишу со стрелкой вверх.
#
# Последняя введенная команда отобразится в командной строке.
# - Продолжайте нажимать клавишу со стрелкой вверх, пока не появится нужная команда, затем нажмите клавишу Return.

# %% [markdown]
# См. также
#
# [Выбор файлов и папок в приложении «Терминал» на Mac](https://support.apple.com/ru-ru/guide/terminal/apd3cf6fe02-3ec8-48f1-951f-866e52955fc8/2.14/mac/15.0)
#
# [Перенаправление ввода и вывода в приложении «Терминал» на Mac](https://support.apple.com/ru-ru/guide/terminal/apd1dbe647b-7e11-49dc-aa76-89aa7e53ce36/2.14/mac/15.0)
#
# [Перетягивание объектов в окно Терминала на Mac](https://support.apple.com/ru-ru/guide/terminal/trml106/2.14/mac/15.0)
#
# [Сочетания клавиш приложения «Терминал» на Mac](https://support.apple.com/ru-ru/guide/terminal/trmlshtcts/2.14/mac/15.0)

# %% [markdown]
# # [Выбор файлов и папок в приложении «Терминал» на Mac](#Руководство-пользователя-Терминала)
#
# [(URL)](https://support.apple.com/ru-ru/guide/terminal/apd3cf6fe02-3ec8-48f1-951f-866e52955fc8/mac)

# %% [markdown]
# Большинство команд работает с файлами и папками, местонахождение которых задается с помощью путей. Имена папок, из которых состоит путь, разделяются с помощью косой черты. Например, путь к приложению «Терминал» имеет следующий вид: /Программы/Утилиты/Terminal.app.

# %% [markdown]
# В следующей таблице показаны стандартные сокращения, используемые для обозначения определенных папок. Сокращения задают пути относительно текущей папки, устраняя необходимость ввода полных путей.

# %% [markdown]
# |Сочетание клавиш|Описание|
# |---|:--|
# |.|Одна точка обозначает текущую папку. Например, строка «. /Test.c» представляет файл Test.c в текущей папке.|
# |..|Две точки обозначают родительскую папку текущей папки. Например, строка «.. /Test» обозначает папку с именем «Test», которая имеет такой же уровень, как у текущей папки.|
# |~|Символ тильды обозначает домашнюю папку текущего пользователя. Например, чтобы указать папку «Documents» текущего пользователя, необходимо ввести ~/Documents.<br/><br/>Чтобы указать папку «Documents» другого пользователя, введите символ тильды ($~$), а затем короткое имя пользователя — например, ~jsmith/Documents.<br/><br/>В macOS эта папка находится в локальной папке /Users или на сетевом сервере.<br/><br/>Чтобы получить список коротких имен на Вашем сервере, введите dscl . -list /Users. Большинство этих пользователей не являются традиционными учетными записями пользователей со своими папками, однако Вы можете найти в этом списке короткие имена известных пользователей на компьютере.|

# %% [markdown]
# Имена файлов и папок могут включать буквы и цифры, а также точку и символ подчеркивания. Не используйте другие символы, например пробелы. Несмотря на то что некоторые файловые системы разрешают использование других символов, включая пробелы, в этом случае вокруг путей может потребоваться добавлять одинарные или двойные кавычки.

# %% [markdown]
# Отдельный символ можно интерпретировать буквально, то есть добавить управляющий символ (escape-символ) обратной косой черты непосредственно перед символом в строке. Например, имя пути My Disk задается как «My Disk» или My\ Disk.

# %% [markdown]
# См. также
#
# [Выполнение команд и запуск инструментов в приложении «Терминал» на Mac](https://support.apple.com/ru-ru/guide/terminal/apdb66b5242-0d18-49fc-9c47-a2498b7c91d5/2.14/mac/15.0)
#
# [Перенаправление ввода и вывода в приложении «Терминал» на Mac](https://support.apple.com/ru-ru/guide/terminal/apd1dbe647b-7e11-49dc-aa76-89aa7e53ce36/2.14/mac/15.0)
#
# [Статья на веб-сайте Apple для разработчиков: основные сведения о командной строке (на английском языке)](https://developer.apple.com/library/content/documentation/OpenSource/Conceptual/ShellScripting/CommandLInePrimer/CommandLine.html)
#
# -------------

# %% [markdown]
# # [Перенаправление ввода и вывода в приложении «Терминал» на Mac](#Руководство-пользователя-Терминала)
#
# [(URL)](https://support.apple.com/ru-ru/guide/terminal/apd1dbe647b-7e11-49dc-aa76-89aa7e53ce36/mac)
